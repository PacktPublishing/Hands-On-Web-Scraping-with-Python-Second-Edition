# %% [markdown]
# ### Exploring Selenium

# %% [markdown]
# #### collect cookies, title, screenshot, page source

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
chromedriver_path="C:\HOWScraping2E\driver\chromedriver.exe"

# %%
service = Service(service=chromedriver_path)
driver = webdriver.Chrome(service=service)

# %% [markdown]
# #### Load 3 different URLS

# %%
urls = {
   'google':'https://www.google.com', 
   'python':'https://www.python.org',
   'selenium':'https://www.selenium.dev'
}

# %% [markdown]
# #### load -> title -> url -> cookies -> screenshot -> page source

# %%
for key,url in urls.items():
    print("loading ",key,"--"*20)
    driver.get(url)
    driver.implicitly_wait(1)  #wait 1 sec
    print(url)
    print(driver.title)
    print(driver.current_url)
    print(driver.get_cookies())    
    driver.get_screenshot_as_file(key+".png")
    print(driver.page_source)
    driver.implicitly_wait(3)  #wait 3 sec before page Refresh
    driver.refresh()
# Out:
# loading  google ----------------------------------------
# https://www.google.com
# Google
# https://www.google.com/
# [{'domain': '.google.com', 'expiry': 1695643250, 'httpOnly': True, 'name': 'NID', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': '511=kK1M4qquNdq2c19qQqdD-QAIVIQnTdSAoMK-qMXEw7GeeTcq56GsNYI5hm6pdy6XBWIomoCZZ43VJacfxmmjVjxNzu_wbZVog51kcYcV4TN-k2kjf3pxpCoVnzw7kOZxDbgj0amlWY0NK2jg0PH1c_Rqc9zlPZs7W6TPj-bsF5g'}, {'domain': '.google.com', 'expiry': 1695384049, 'httpOnly': True, 'name': 'AEC', 'path': '/', 'sameSite': 'Lax', 'secure': True, 'value': 'AUEFqZfLEalKxzdiR0H6s2v4LgI2ic6RVYHZH2nnmwru2TDYq5hAjq4DWQ'}, {'domain': '.google.com', 'expiry': 1682424050, 'httpOnly': False, 'name': '1P_JAR', 'path': '/', 'sameSite': 'None', 'secure': True, 'value': '2023-03-26-12'}]
# ...

# %% [markdown]
# #### Move back twice and forward once (History Tabs)

# %%
driver.back() #history Python.org
driver.back() #history Google.com

# %%
driver.forward() # history Python.org

# %%
driver.quit() #  closes the browser and terminates the session

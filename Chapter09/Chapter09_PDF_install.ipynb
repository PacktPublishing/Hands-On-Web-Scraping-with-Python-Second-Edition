# %% [markdown]
# ### pypdf2 Python library for PDF

# %%
#!pip install pypdf2    # install pypdf2 (https://pypdf2.readthedocs.io/en/3.0.0/user/installation.html)
# Out:
# ...
#      ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/232.6 kB 640.0 kB/s eta 0:00:01
#      --------- --------------------------- 61.4/232.6 kB 544.7 kB/s eta 0:00:01
#      -------------- ---------------------- 92.2/232.6 kB 655.4 kB/s eta 0:00:01
#      ------------------- ---------------- 122.9/232.6 kB 654.9 kB/s eta 0:00:01
#      ------------------------------ ----- 194.6/232.6 kB 784.3 kB/s eta 0:00:01
#      ---------------------------------- - 225.3/232.6 kB 860.2 kB/s eta 0:00:01
#      ---------------------------------- - 225.3/232.6 kB 860.2 kB/s eta 0:00:01
#      ------------------------------------ 232.6/232.6 kB 646.3 kB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#!pip install pypdf2[full]  #install pypdf2 with all dependencies
# Out:
# ...
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.7 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.7 MB 487.6 kB/s eta 0:00:04
#      -- ------------------------------------- 0.1/1.7 MB 655.4 kB/s eta 0:00:03
#      -- ------------------------------------- 0.1/1.7 MB 819.2 kB/s eta 0:00:02
#      -- ------------------------------------- 0.1/1.7 MB 819.2 kB/s eta 0:00:02
#      --- ------------------------------------ 0.1/1.7 MB 566.5 kB/s eta 0:00:03
#      ---- ----------------------------------- 0.2/1.7 MB 620.6 kB/s eta 0:00:03
#      ----- ---------------------------------- 0.2/1.7 MB 655.6 kB/s eta 0:00:03
#      ----- ---------------------------------- 0.2/1.7 MB 655.6 kB/s eta 0:00:03
#      ----- ---------------------------------- 0.2/1.7 MB 655.6 kB/s eta 0:00:03
#      ----- ---------------------------------- 0.3/1.7 MB 491.5 kB/s eta 0:00:04
# ...

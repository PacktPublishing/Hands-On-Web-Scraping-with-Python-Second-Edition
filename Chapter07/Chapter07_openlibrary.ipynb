# %% [markdown]
# ### OpenLibrary: Python - Wes M

# %%
import requests
import csv

# %%
subject="python"
author="Wes"

# %%
apiUrl="https://openlibrary.org/search.json?q="+subject+"&author="+author

# %% [markdown]
# #### HTTP Request Headers (from Curl)

# %%
headers={
  'Upgrade-Insecure-Requests': '1',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'
}

# %%
response = requests.get(apiUrl, headers=headers).json()

# %%
response
# Out:
# {'numFound': 11,
#  'start': 0,
#  'numFoundExact': True,
#  'docs': [{'key': '/works/OL17422847W',
#    'type': 'work',
#    'seed': ['/books/OL26005473M',
#     '/books/OL37924259M',
#     '/books/OL39563022M',
#     '/books/OL39554203M',
#     '/works/OL17422847W',
#     '/subjects/programming_languages_(electronic_computers)',
#     '/subjects/python_(computer_program_language)',
#     '/subjects/data_mining',
#     '/subjects/python_(computer_program_language)',
#     '/authors/OL7309633A'],
#    'title': 'Python For Data Analysis',
#    'title_suggest': 'Python For Data Analysis',
#    'title_sort': 'Python For Data Analysis',
#    'edition_count': 4,
#    'edition_key': ['OL26005473M', 'OL37924259M', 'OL39563022M', 'OL39554203M'],
#    'publish_date': ['Oct 04, 2022', '2012', '2022'],
#    'publish_year': [2012, 2022],
#    'first_publish_year': 2012,
#    'number_of_pages_median': 550,
#    'lccn': ['2012538094'],
#    'oclc': ['973821819', '794362690'],
# ...

# %%
len(response)
# Out:
# 7

# %% [markdown]
# #### Collecting only fields 'title','publish_date','publisher','author_name','subject_key'

# %%
lists=[]

# %%
for book in response['docs']:
    if 'subject_key' in book:        
        lists.append([
            book['title'],book['publish_date'][0],book['publisher'][0],book['author_name'][0],"|".join(book['subject_key'])
        ])
    else:        
        lists.append([book['title'],book['publish_date'][0],book['publisher'][0],book['author_name'][0],''])

# %%
lists
# Out:
# [['Python For Data Analysis',
#   'Oct 04, 2022',
#   "O'Reilly Media, Incorporated",
#   'Wes McKinney',
#   'data_mining|programming_languages_(electronic_computers)|python_(computer_program_language)'],
#  ['Python Programming for Beginners',
#   '2019',
#   'Independently Published',
#   'Jason Wes',
#   ''],
#  ['Python for Data Analysis',
#   '2019',
#   'Independently Published',
#   'Clark Wes',
#   ''],
#  ['Python for Data Analysis',
#   '2012',
#   "O'Reilly Media, Incorporated",
#   'Wes Mckinney',
#   ''],
#  ['Python for Data Science',
#   '2019',
#   'Independently Published',
#   'Jason Wes',
#   ''],
#  ['Python Programming Language for Beginners',
#   '2019',
#   'Independently Published',
#   'Clark Wes',
#   ''],
#  ['Python Para Análise de Dados',
#   'Sep 07, 2000',
#   'Novatec',
#   'Wes McKinney',
#   ''],
#  ['Genuine _ use Python for data analysis(Chinese Edition)',
#   'Jan 01, 2014',
#   'Machinery Industry Press',
#   'MAI JIN NI (Wes McKinney)',
# ...

# %% [markdown]
# #### Convert List(dataSet) to CSV

# %%
def writeto_csv(data,filename,columns):
    with open(filename,'w+',newline='',encoding="UTF-8") as file:
        writer = csv.DictWriter(file,fieldnames=columns) #Column header
        writer.writeheader()
        writer = csv.writer(file)
        for element in data:
            writer.writerows([element])

# %%
writeto_csv(lists,'python_wes.csv',['book_title','published_date','publisher','author','subjects'])
